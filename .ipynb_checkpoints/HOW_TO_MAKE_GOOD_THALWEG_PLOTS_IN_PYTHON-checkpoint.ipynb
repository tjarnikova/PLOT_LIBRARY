# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
import matplotlib
import numpy as np
import scipy as sp
import cmocean as cm
# %matplotlib inline

# %% [markdown]
# ## Depth profiles by year
# #### color of line in linspace, sharing y axis, inverting y axis

# %%
matplotlib.rcParams['font.sans-serif'] = "Comic Sans MS"
# Then, "ALWAYS use sans-serif fonts"
matplotlib.rcParams['font.family'] = "sans-serif"
depths = np.arange(0,10,0.1)
fake_data = np.sin(depths)
fake_data2 = np.cos(depths)

csfont = {'fontname':'Comic Sans MS'}
hfont = {'fontname':'Helvetica'}



n = 12
colors = cm.cm.haline(np.linspace(0,1,n))
colors2 = cm.cm.phase(np.linspace(0,1,n))
fig, (ax, ax2) = plt.subplots(1, 2, figsize=(10, 5), sharey=True)
ax.invert_yaxis()
for i in range(12):
    ax.plot(fake_data+i*0.1,depths, linestyle = '-', color = colors[i])

ax.invert_yaxis()
for i in range(12):
    ax2.plot(fake_data2+i*0.1,depths, linestyle = '-', color = colors2[i])

plt.suptitle('Lines for fun', fontsize = 20)

# %% [markdown]
# ### Odd configurations of plots
